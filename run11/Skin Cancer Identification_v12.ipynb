# %% [markdown]
# # Loading Dependencies

# %%
# Dependencies to Visualize the model
import tensorflow as tf
# %matplotlib inline
from IPython.display import Image, SVG
import matplotlib.pyplot as plt
import numpy as np
# Setting seed for reproducibility
np.random.seed(0)

# Filepaths, pandas, numpy, Tensorflow, and scikit-image
import os
import pandas as pd
import numpy as np
import tensorflow as tf
import skimage as sk

# %% [markdown]
# # Stratify Images in Main Image Repository
# Only run if images are still conglomerated

# %%
import os
import shutil
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the CSV file
csv_file = "Resources/HAM10000_metadata.csv"
metadata = pd.read_csv(csv_file)

# Define the source directory where all the images are located
source_dir = "Resources/Skin Cancer"

# Define the target directories for train and val splits
train_dir = "Resources/Skin Cancer/train"
val_dir = "Resources/Skin Cancer/val"

# Define the split ratio (e.g., 0.8 for 80% train, 0.2 for 20% val)
split_ratio = 0.8

# Create the target directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)

# Get the unique class labels
class_labels = metadata["dx"].unique()

# Create subdirectories for each class in train and val directories
for label in class_labels:
    os.makedirs(os.path.join(train_dir, label), exist_ok=True)
    os.makedirs(os.path.join(val_dir, label), exist_ok=True)

# Split the metadata into train and validation sets using stratified splitting
# Stratify was required here to ensure that an 80-20 split occured for all classes in the dataset, not just an 80-20 split of the entire dataset.
train_metadata, val_metadata = train_test_split(
    metadata, stratify=metadata["dx"], test_size=1 - split_ratio, random_state=42
)

# Move or copy the images to the respective train and validation directories
for _, row in train_metadata.iterrows():
    image_id = row["image_id"]
    image_path = os.path.join(source_dir, f"{image_id}.jpg")
    class_label = row["dx"]
    target_dir = os.path.join(train_dir, class_label)
    shutil.copy(image_path, target_dir)

for _, row in val_metadata.iterrows():
    image_id = row["image_id"]
    image_path = os.path.join(source_dir, f"{image_id}.jpg")
    class_label = row["dx"]
    target_dir = os.path.join(val_dir, class_label)
    shutil.copy(image_path, target_dir)

print("Stratified splitting and image organization completed.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 44
#      42     class_label = row["dx"]
#      43     target_dir = os.path.join(train_dir, class_label)
# ---> 44     shutil.copy(image_path, target_dir)
#      46 for _, row in val_metadata.iterrows():
#      47     image_id = row["image_id"]
#
# File c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# --> 427 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     428 copymode(src, dst, follow_symlinks=follow_symlinks)
#     429 return dst
#
# File c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\shutil.py:264, in copyfile(src, dst, follow_symlinks)
#     262     os.symlink(os.readlink(src), dst)
#     263 else:
# --> 264     with open(src, 'rb') as fsrc:
#     265         try:
#     266             with open(dst, 'wb') as fdst:
#     267                 # macOS
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources/Skin Cancer\\ISIC_0033319.jpg'

# %% [markdown]
# # Preprocessing of Images

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define the path to your image directory
image_directory = "Resources/Skin Cancer"

# Defining original image size
image_size = (600, 450)

# Define the batch size
batch_size = 32

# EDIT THIS OUT 
# Create an ImageDataGenerator for data augmentation
train_datagen = ImageDataGenerator(
    rescale=1.0 / 255,  # Normalize pixel values
    # rotation_range=20,  # Randomly rotate images by 20 degrees
    # width_shift_range=0.2,  # Randomly shift images horizontally by 20%
    # height_shift_range=0.2,  # Randomly shift images vertically by 20%
    # horizontal_flip=True,  # Randomly flip images horizontally
    # zoom_range=0.2,  # Randomly zoom images by 20%
)

# Load and preprocess the train dataset with data augmentation
train_dataset = train_datagen.flow_from_directory(
    directory=os.path.join(image_directory, "train"),  # Use the 'train' directory
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42,
)

# Create an ImageDataGenerator for validation data (no augmentation)
val_datagen = ImageDataGenerator(rescale=1.0 / 255)  # Normalize pixel values

# Load and preprocess the validation dataset without data augmentation
val_dataset = val_datagen.flow_from_directory(
    directory=os.path.join(image_directory, "val"),  # Use the 'val' directory
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
    seed=42,
)

def get_class_counts(dataset):
    class_labels = list(dataset.class_indices.keys())
    class_counts = dict(zip(class_labels, [0] * len(class_labels)))
    for _, labels in dataset:
        for label in labels:
            class_counts[class_labels[int(label.argmax())]] += 1
        if sum(class_counts.values()) >= dataset.samples:
            break
    return class_counts

train_counts = get_class_counts(train_dataset)
val_counts = get_class_counts(val_dataset)

# Combine the counts from training and validation
combined_counts = {class_name: train_counts.get(class_name, 0) + val_counts.get(class_name, 0) for class_name in set(train_counts) | set(val_counts)}
total_samples = sum(combined_counts.values())

print("\nOverall Dataset Class Distribution:")
print(f"Total samples across train and validation datasets: {total_samples}")
for class_name, count in combined_counts.items():
    percentage = (count / total_samples) * 100
    print(f"{class_name}: {count} ({percentage:.2f}%)")

# Print class distribution for training and validation datasets individually
print("\nTrain Dataset Class Distribution:")
for class_name, count in train_counts.items():
    percentage = (count / train_dataset.samples) * 100
    print(f"{class_name}: {count} ({percentage:.2f}%)")

print("\nValidation Dataset Class Distribution:")
for class_name, count in val_counts.items():
    percentage = (count / val_dataset.samples) * 100
    print(f"{class_name}: {count} ({percentage:.2f}%)")

# Print the class names and dataset shapes
print("\nSummary:")
print("Class Names:", list(train_dataset.class_indices.keys()))
print("Train Dataset Shape:", train_dataset.image_shape)
print("Validation Dataset Shape:", val_dataset.image_shape)
# Out:
# Found 8012 images belonging to 7 classes.
# Found 2003 images belonging to 7 classes.
#
# Overall Dataset Class Distribution:
# Total samples across train and validation datasets: 10015
# bcc: 514 (5.13%)
# vasc: 142 (1.42%)
# nv: 6705 (66.95%)
# akiec: 327 (3.27%)
# mel: 1113 (11.11%)
# df: 115 (1.15%)
# bkl: 1099 (10.97%)
#
# Train Dataset Class Distribution:
# akiec: 262 (3.27%)
# bcc: 411 (5.13%)
# bkl: 879 (10.97%)
# df: 92 (1.15%)
# mel: 890 (11.11%)
# nv: 5364 (66.95%)
# vasc: 114 (1.42%)
#
# Validation Dataset Class Distribution:
# akiec: 65 (3.25%)
# bcc: 103 (5.14%)
# bkl: 220 (10.98%)
# df: 23 (1.15%)
# mel: 223 (11.13%)
# nv: 1341 (66.95%)
# vasc: 28 (1.40%)
#
# Summary:
# Class Names: ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
# Train Dataset Shape: (600, 450, 3)
# Validation Dataset Shape: (600, 450, 3)

# %% [markdown]
# # Continuous Testing
# This section contains a conglomerated model run. It was created so that the models could be tested overnight. I'm going to bed now.

# %%
# Importing Dependencies
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger

import csv
import os

from sklearn.utils import class_weight

# ///////////////////////////////////////////////////////////////////////////////////////////
# CHECK RUN NUMBER BEFORE RUNNING
# Run Number - use to create new directory or add to existing directory
run_number = 11
run_dir = f"run{run_number}"
os.makedirs(run_dir, exist_ok=True)

# ///////////////////////////////////////////////////////////////////////////////////////////


# Creating a CSV file to store the model results
csv_file = "model_results.csv"
fieldnames = [
    "architecture",
    "optimizer",
    "loss",
    "accuracy",
    "precision",
    "recall",
    "auc",
]

# Write the header to the CSV file. Data is written to the file after model_result
with open(csv_file, mode="w", newline="") as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writeheader()

batch_size = 32
architectures = ["ResNet50","VGG16","InceptionV3"]  # Options: "VGG16", "ResNet50", "InceptionV3"
optimizers = ["Adam","SGD"]  # Options: "Adam", "RMSprop", "SGD"

# Create directory to store models
models_dir = f"{run_dir}/models"
os.makedirs(models_dir, exist_ok=True)

# Initialize model_results to store the evaluation results
model_results = []

for architecture in architectures:
    # Set the input shape and preprocessing function based on the selected architecture
    if architecture == "VGG16" :
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.vgg16.preprocess_input
    elif architecture == "ResNet50":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.resnet50.preprocess_input
    elif architecture == "InceptionV3":
        input_shape = (299, 299, 3)
        preprocessing_function = tf.keras.applications.inception_v3.preprocess_input

    # Load and preprocess data using tf.keras.preprocessing
    # This adds data augmentation to the training dataset
    train_datagen = ImageDataGenerator(
        preprocessing_function=preprocessing_function,
        # rotation_range=20,
        # width_shift_range=0.2,
        # height_shift_range=0.2,
        # horizontal_flip=True,
    )

    train_dataset = train_datagen.flow_from_directory(
        "Resources/Skin Cancer/train",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    
    val_datagen = ImageDataGenerator(preprocessing_function=preprocessing_function)

    # Define the validation dataset without data augmentation
    val_dataset = val_datagen.flow_from_directory(
        "Resources/Skin Cancer/val",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    # Define the pre-trained model architecture. Will select proper model based on current 'architecture' in for loop
    if architecture == "VGG16":
        base_model = VGG16(
            weights="imagenet", include_top=False, input_shape=input_shape
        )
    elif architecture == "ResNet50":
        base_model = ResNet50(
            weights="imagenet", include_top=False, input_shape=input_shape
        )
    elif architecture == "InceptionV3":
        base_model = InceptionV3(
            weights="imagenet", include_top=False, input_shape=input_shape
        )

    # Freeze the layers of the pre-trained model
    for layer in base_model.layers:
        layer.trainable = False

    # Get the number of unique classes from the train_dataset
    num_classes = len(train_dataset.class_indices)

   # Add custom layers on top of the pre-trained model
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation="relu")(x)
    x = Dropout(0.5)(x)
    predictions = Dense(num_classes, activation="softmax")(x)

    # Create the final model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Step through and adjust for each optimizer
    for optimizer_name in optimizers:
        # Define the optimizer
        if optimizer_name == "Adam":
            optimizer = Adam(learning_rate=0.001)
        elif optimizer_name == "RMSprop":
            optimizer = RMSprop(learning_rate=0.001)
        elif optimizer_name == "SGD":
            optimizer = SGD(learning_rate=0.001, momentum=0.9)

        # Create learning rate scheduler that monitors validation loss
        lr_scheduler = ReduceLROnPlateau(
            monitor="val_loss", factor=0.1, patience=5, verbose=1
        )

       
       # Compile the model
        model.compile(
            optimizer=optimizer,
            loss="categorical_crossentropy",
            metrics=["accuracy", Precision(), Recall(), AUC()],
        )
        # Create a TensorBoard callback with a separate log directory for each model and optimizer
        tensorboard_callback = TensorBoard(
            log_dir=f"./{run_dir}/logs/{architecture}_{optimizer_name}",
            histogram_freq=1,
        )

        # Create an EarlyStopping callback to prevent overfitting
        early_stopping = EarlyStopping(
            monitor="val_loss", patience=5, restore_best_weights=True
        )

        # Create a ModelCheckpoint callback to save the best model weights
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
            filepath=os.path.join(
                models_dir, f"model_{architecture}_{optimizer_name}.weights.h5"
            ),
            save_weights_only=True,
            save_best_only=True,
            monitor="val_loss",
            verbose=1,
        )

        # Create a CSVLogger callback with keras
        csv_logger = CSVLogger(
            os.path.join(
                models_dir, f"model_{architecture}_{optimizer_name}_training.csv"
            )
        )

        # Calculate class weights using sklearn's class_weight
        class_weights = class_weight.compute_class_weight(
            'balanced',
            classes=np.unique(train_dataset.classes),
            y=train_dataset.classes
        )
        class_weight_dict = dict(enumerate(class_weights))
      
        # Train the model with the checkpoint callback and weights
        epochs = 25
        history = model.fit(
            train_dataset,
            steps_per_epoch=train_dataset.samples // batch_size,
            validation_data=val_dataset,
            validation_steps=val_dataset.samples // batch_size,
            epochs=epochs,
            class_weight=class_weight_dict,
            callbacks=[
                tensorboard_callback,
                lr_scheduler,
                checkpoint_callback,
                csv_logger,
            ],
        )

        # Save the optimizer state to avoid retraining the model
        model.save(
            os.path.join(models_dir, f"model_{architecture}_{optimizer_name}.h5")
        )

         # Evaluate the model on the validation set and print the results
        loss, accuracy, precision, recall, auc = model.evaluate(val_dataset)
        print(f"Model: {architecture}, Optimizer: {optimizer_name}")
        print(f"Validation Loss: {loss:.4f}")
        print(f"Validation Accuracy: {accuracy:.4f}")
        print(f"Validation Precision: {precision:.4f}")
        print(f"Validation Recall: {recall:.4f}")
        print(f"Validation AUC-ROC: {auc:.4f}")
        print(class_weights)
        print(class_weight_dict)

        # Append the model results to the list
        model_result = {
            "architecture": architecture,
            "optimizer": optimizer_name,
            "loss": loss,
            "accuracy": accuracy,
            "precision": precision,
            "recall": recall,
            "auc": auc,
        }
        model_results.append(model_result)

        # Write the current model result to the CSV file
        with open(csv_file, mode="a", newline="") as file:
            writer = csv.DictWriter(file, fieldnames=fieldnames)
            writer.writerow(model_result)

        # Save the model
        model.save(
            os.path.join(models_dir, f"model_{architecture}_{optimizer_name}.h5")
        )
# Out:
# Found 8012 images belonging to 7 classes.
# Found 2003 images belonging to 7 classes.
# Epoch 1/25
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 723ms/step - accuracy: 0.4004 - auc: 0.7623 - loss: 2.6617 - precision: 0.4339 - recall: 0.3511
# Epoch 1: val_loss improved from inf to 1.58041, saving model to run11/models\model_ResNet50_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 234s 915ms/step - accuracy: 0.4005 - auc: 0.7625 - loss: 2.6593 - precision: 0.4341 - recall: 0.3512 - val_accuracy: 0.4138 - val_auc: 0.8017 - val_loss: 1.5804 - val_precision: 0.5005 - val_recall: 0.2777 - learning_rate: 0.0010
# Epoch 2/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:47 913ms/step - accuracy: 0.3438 - auc: 0.7537 - loss: 1.5981 - precision: 0.4737 - recall: 0.2812
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss improved from 1.58041 to 0.93379, saving model to run11/models\model_ResNet50_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.3438 - auc: 0.7537 - loss: 0.8022 - precision: 0.4737 - recall: 0.2812 - val_accuracy: 0.3158 - val_auc: 0.7832 - val_loss: 0.9338 - val_precision: 0.2143 - val_recall: 0.1579 - learning_rate: 0.0010
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 718ms/step - accuracy: 0.5528 - auc: 0.8770 - loss: 1.1385 - precision: 0.6515 - recall: 0.4408
# Epoch 3: val_loss did not improve from 0.93379
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 226s 903ms/step - accuracy: 0.5528 - auc: 0.8771 - loss: 1.1386 - precision: 0.6515 - recall: 0.4409 - val_accuracy: 0.5449 - val_auc: 0.8891 - val_loss: 1.1453 - val_precision: 0.6833 - val_recall: 0.4012 - learning_rate: 0.0010
# Epoch 4/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:59 721ms/step - accuracy: 0.4688 - auc: 0.8212 - loss: 1.0002 - precision: 0.4737 - recall: 0.2812
# Epoch 4: val_loss improved from 0.93379 to 0.54581, saving model to run11/models\model_ResNet50_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.4688 - auc: 0.8212 - loss: 0.5021 - precision: 0.4737 - recall: 0.2812 - val_accuracy: 0.6316 - val_auc: 0.8966 - val_loss: 0.5458 - val_precision: 0.7273 - val_recall: 0.4211 - learning_rate: 0.0010
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 716ms/step - accuracy: 0.5702 - auc: 0.8870 - loss: 1.1256 - precision: 0.6721 - recall: 0.4534
# Epoch 5: val_loss did not improve from 0.54581
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 226s 901ms/step - accuracy: 0.5703 - auc: 0.8871 - loss: 1.1254 - precision: 0.6721 - recall: 0.4535 - val_accuracy: 0.6467 - val_auc: 0.9327 - val_loss: 0.8947 - val_precision: 0.7704 - val_recall: 0.5580 - learning_rate: 0.0010
# Epoch 6/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:54 701ms/step - accuracy: 0.5625 - auc: 0.9132 - loss: 0.8791 - precision: 0.6364 - recall: 0.4375
# Epoch 6: val_loss improved from 0.54581 to 0.39512, saving model to run11/models\model_ResNet50_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.5625 - auc: 0.9132 - loss: 0.4413 - precision: 0.6364 - recall: 0.4375 - val_accuracy: 0.6316 - val_auc: 0.9471 - val_loss: 0.3951 - val_precision: 0.7333 - val_recall: 0.5789 - learning_rate: 0.0010
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - accuracy: 0.6196 - auc: 0.9169 - loss: 0.9893 - precision: 0.7103 - recall: 0.5345
# Epoch 7: val_loss did not improve from 0.39512
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 226s 900ms/step - accuracy: 0.6196 - auc: 0.9168 - loss: 0.9894 - precision: 0.7102 - recall: 0.5345 - val_accuracy: 0.6159 - val_auc: 0.9179 - val_loss: 1.0228 - val_precision: 0.6854 - val_recall: 0.5292 - learning_rate: 0.0010
# Epoch 8/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:55 705ms/step - accuracy: 0.5312 - auc: 0.8548 - loss: 1.1967 - precision: 0.5600 - recall: 0.4375
# Epoch 8: val_loss did not improve from 0.39512
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5312 - auc: 0.8548 - loss: 0.6007 - precision: 0.5600 - recall: 0.4375 - val_accuracy: 0.6316 - val_auc: 0.9229 - val_loss: 0.4798 - val_precision: 0.6250 - val_recall: 0.5263 - learning_rate: 0.0010
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.6319 - auc: 0.9213 - loss: 0.9093 - precision: 0.7199 - recall: 0.5495
# Epoch 9: val_loss did not improve from 0.39512
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 879ms/step - accuracy: 0.6319 - auc: 0.9213 - loss: 0.9095 - precision: 0.7198 - recall: 0.5494 - val_accuracy: 0.6552 - val_auc: 0.9357 - val_loss: 0.8798 - val_precision: 0.8022 - val_recall: 0.5212 - learning_rate: 0.0010
# Epoch 10/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:56 710ms/step - accuracy: 0.6250 - auc: 0.9268 - loss: 1.4277 - precision: 0.6500 - recall: 0.4062
# Epoch 10: val_loss improved from 0.39512 to 0.32088, saving model to run11/models\model_ResNet50_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6250 - auc: 0.9268 - loss: 0.7167 - precision: 0.6500 - recall: 0.4062 - val_accuracy: 0.8421 - val_auc: 0.9730 - val_loss: 0.3209 - val_precision: 0.9286 - val_recall: 0.6842 - learning_rate: 0.0010
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.6103 - auc: 0.9198 - loss: 0.8627 - precision: 0.7066 - recall: 0.5148
# Epoch 11: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.6103 - auc: 0.9198 - loss: 0.8629 - precision: 0.7066 - recall: 0.5149 - val_accuracy: 0.7061 - val_auc: 0.9499 - val_loss: 0.7666 - val_precision: 0.8377 - val_recall: 0.6089 - learning_rate: 0.0010
# Epoch 12/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:58 717ms/step - accuracy: 0.7188 - auc: 0.9745 - loss: 0.7358 - precision: 0.8400 - recall: 0.6562
# Epoch 12: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7188 - auc: 0.9745 - loss: 0.3694 - precision: 0.8400 - recall: 0.6562 - val_accuracy: 0.4211 - val_auc: 0.9120 - val_loss: 0.5151 - val_precision: 0.6154 - val_recall: 0.4211 - learning_rate: 0.0010
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 699ms/step - accuracy: 0.6407 - auc: 0.9252 - loss: 0.8622 - precision: 0.7295 - recall: 0.5592
# Epoch 13: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 221s 880ms/step - accuracy: 0.6407 - auc: 0.9252 - loss: 0.8622 - precision: 0.7295 - recall: 0.5591 - val_accuracy: 0.5015 - val_auc: 0.8675 - val_loss: 1.3242 - val_precision: 0.5694 - val_recall: 0.4052 - learning_rate: 0.0010
# Epoch 14/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:50 685ms/step - accuracy: 0.5625 - auc: 0.8836 - loss: 0.7097 - precision: 0.5714 - recall: 0.3750
# Epoch 14: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5625 - auc: 0.8836 - loss: 0.3562 - precision: 0.5714 - recall: 0.3750 - val_accuracy: 0.5789 - val_auc: 0.8183 - val_loss: 0.8553 - val_precision: 0.6154 - val_recall: 0.4211 - learning_rate: 0.0010
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.5948 - auc: 0.9063 - loss: 0.8511 - precision: 0.6720 - recall: 0.4958
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 15: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 878ms/step - accuracy: 0.5949 - auc: 0.9063 - loss: 0.8511 - precision: 0.6721 - recall: 0.4959 - val_accuracy: 0.6764 - val_auc: 0.9515 - val_loss: 0.7514 - val_precision: 0.7801 - val_recall: 0.5882 - learning_rate: 0.0010
# Epoch 16/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:48 678ms/step - accuracy: 0.5938 - auc: 0.9432 - loss: 0.3083 - precision: 0.6071 - recall: 0.5312
# Epoch 16: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5938 - auc: 0.9432 - loss: 0.1548 - precision: 0.6071 - recall: 0.5312 - val_accuracy: 0.6842 - val_auc: 0.9534 - val_loss: 0.3969 - val_precision: 0.9167 - val_recall: 0.5789 - learning_rate: 1.0000e-04
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.6665 - auc: 0.9452 - loss: 0.7195 - precision: 0.7714 - recall: 0.5845
# Epoch 17: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.6665 - auc: 0.9452 - loss: 0.7194 - precision: 0.7714 - recall: 0.5845 - val_accuracy: 0.6840 - val_auc: 0.9493 - val_loss: 0.7747 - val_precision: 0.7910 - val_recall: 0.6048 - learning_rate: 1.0000e-04
# Epoch 18/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:52 693ms/step - accuracy: 0.7812 - auc: 0.9523 - loss: 0.8194 - precision: 0.8462 - recall: 0.6875
# Epoch 18: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7812 - auc: 0.9523 - loss: 0.4113 - precision: 0.8462 - recall: 0.6875 - val_accuracy: 0.5263 - val_auc: 0.9162 - val_loss: 0.4888 - val_precision: 0.5385 - val_recall: 0.3684 - learning_rate: 1.0000e-04
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.6860 - auc: 0.9492 - loss: 0.6165 - precision: 0.7648 - recall: 0.5994
# Epoch 19: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 878ms/step - accuracy: 0.6861 - auc: 0.9492 - loss: 0.6165 - precision: 0.7648 - recall: 0.5994 - val_accuracy: 0.6956 - val_auc: 0.9520 - val_loss: 0.7530 - val_precision: 0.7918 - val_recall: 0.6210 - learning_rate: 1.0000e-04
# Epoch 20/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:49 680ms/step - accuracy: 0.7188 - auc: 0.9640 - loss: 0.7003 - precision: 0.8462 - recall: 0.6875
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 20: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7188 - auc: 0.9640 - loss: 0.3515 - precision: 0.8462 - recall: 0.6875 - val_accuracy: 0.6842 - val_auc: 0.9534 - val_loss: 0.3737 - val_precision: 0.8000 - val_recall: 0.6316 - learning_rate: 1.0000e-04
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.6963 - auc: 0.9519 - loss: 0.5745 - precision: 0.7761 - recall: 0.6207
# Epoch 21: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 878ms/step - accuracy: 0.6963 - auc: 0.9519 - loss: 0.5746 - precision: 0.7761 - recall: 0.6207 - val_accuracy: 0.7011 - val_auc: 0.9530 - val_loss: 0.7465 - val_precision: 0.7898 - val_recall: 0.6250 - learning_rate: 1.0000e-05
# Epoch 22/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:54 702ms/step - accuracy: 0.5625 - auc: 0.9348 - loss: 0.5199 - precision: 0.5909 - recall: 0.4062
# Epoch 22: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5625 - auc: 0.9348 - loss: 0.2610 - precision: 0.5909 - recall: 0.4062 - val_accuracy: 0.6842 - val_auc: 0.9642 - val_loss: 0.3433 - val_precision: 0.7059 - val_recall: 0.6316 - learning_rate: 1.0000e-05
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.7139 - auc: 0.9536 - loss: 0.5778 - precision: 0.7884 - recall: 0.6294
# Epoch 23: val_loss did not improve from 0.32088
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 221s 880ms/step - accuracy: 0.7138 - auc: 0.9536 - loss: 0.5779 - precision: 0.7883 - recall: 0.6294 - val_accuracy: 0.7006 - val_auc: 0.9533 - val_loss: 0.7423 - val_precision: 0.7916 - val_recall: 0.6260 - learning_rate: 1.0000e-05
# Epoch 24/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:53 696ms/step - accuracy: 0.6875 - auc: 0.9203 - loss: 0.5341 - precision: 0.7407 - recall: 0.6250
# Epoch 24: val_loss improved from 0.32088 to 0.25374, saving model to run11/models\model_ResNet50_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc: 0.9203 - loss: 0.2681 - precision: 0.7407 - recall: 0.6250 - val_accuracy: 0.7895 - val_auc: 0.9813 - val_loss: 0.2537 - val_precision: 0.8235 - val_recall: 0.7368 - learning_rate: 1.0000e-05
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.7107 - auc: 0.9570 - loss: 0.5619 - precision: 0.7907 - recall: 0.6342
# Epoch 25: val_loss did not improve from 0.25374
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 877ms/step - accuracy: 0.7106 - auc: 0.9569 - loss: 0.5620 - precision: 0.7907 - recall: 0.6342 - val_accuracy: 0.7001 - val_auc: 0.9535 - val_loss: 0.7410 - val_precision: 0.7868 - val_recall: 0.6250 - learning_rate: 1.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 43s 687ms/step - accuracy: 0.7022 - auc: 0.9533 - loss: 0.7435 - precision: 0.7873 - recall: 0.6165
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: ResNet50, Optimizer: Adam
# Validation Loss: 0.7373
# Validation Accuracy: 0.7024
# Validation Precision: 0.9540
# Validation Recall: 0.7883
# Validation AUC-ROC: 0.6266
# [ 4.36859324  2.78484532  1.30212904 12.44099379  1.28603531  0.21338021
#  10.04010025]
# {0: 4.368593238822246, 1: 2.7848453249913105, 2: 1.3021290427433772, 3: 12.440993788819876, 4: 1.2860353130016051, 5: 0.21338020666879728, 6: 10.040100250626567}
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.6866 - auc_1: 0.9501 - loss: 0.6340 - precision_1: 0.7693 - recall_1: 0.6115
# Epoch 1: val_loss improved from inf to 0.79066, saving model to run11/models\model_ResNet50_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 225s 883ms/step - accuracy: 0.6867 - auc_1: 0.9501 - loss: 0.6340 - precision_1: 0.7693 - recall_1: 0.6115 - val_accuracy: 0.6779 - val_auc_1: 0.9482 - val_loss: 0.7907 - val_precision_1: 0.7609 - val_recall_1: 0.6159 - learning_rate: 0.0010
# Epoch 2/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:52 692ms/step - accuracy: 0.6875 - auc_1: 0.9595 - loss: 0.6913 - precision_1: 0.8182 - recall_1: 0.5625
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss improved from 0.79066 to 0.31447, saving model to run11/models\model_ResNet50_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc_1: 0.9595 - loss: 0.3471 - precision_1: 0.8182 - recall_1: 0.5625 - val_accuracy: 0.8421 - val_auc_1: 0.9661 - val_loss: 0.3145 - val_precision_1: 0.8421 - val_recall_1: 0.8421 - learning_rate: 0.0010
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.6975 - auc_1: 0.9511 - loss: 0.6207 - precision_1: 0.7706 - recall_1: 0.6279
# Epoch 3: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.6976 - auc_1: 0.9511 - loss: 0.6206 - precision_1: 0.7706 - recall_1: 0.6279 - val_accuracy: 0.7061 - val_auc_1: 0.9572 - val_loss: 0.7137 - val_precision_1: 0.7697 - val_recall_1: 0.6436 - learning_rate: 0.0010
# Epoch 4/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:50 687ms/step - accuracy: 0.7188 - auc_1: 0.9425 - loss: 0.5629 - precision_1: 0.7917 - recall_1: 0.5938
# Epoch 4: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7188 - auc_1: 0.9425 - loss: 0.2826 - precision_1: 0.7917 - recall_1: 0.5938 - val_accuracy: 0.6842 - val_auc_1: 0.9548 - val_loss: 0.3766 - val_precision_1: 0.7647 - val_recall_1: 0.6842 - learning_rate: 0.0010
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.7138 - auc_1: 0.9583 - loss: 0.5780 - precision_1: 0.7808 - recall_1: 0.6593
# Epoch 5: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.7138 - auc_1: 0.9583 - loss: 0.5780 - precision_1: 0.7808 - recall_1: 0.6593 - val_accuracy: 0.7283 - val_auc_1: 0.9580 - val_loss: 0.7018 - val_precision_1: 0.8033 - val_recall_1: 0.6462 - learning_rate: 0.0010
# Epoch 6/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:54 700ms/step - accuracy: 0.7188 - auc_1: 0.9623 - loss: 0.6368 - precision_1: 0.7857 - recall_1: 0.6875
# Epoch 6: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7188 - auc_1: 0.9623 - loss: 0.3197 - precision_1: 0.7857 - recall_1: 0.6875 - val_accuracy: 0.8947 - val_auc_1: 0.9591 - val_loss: 0.3465 - val_precision_1: 0.8667 - val_recall_1: 0.6842 - learning_rate: 0.0010
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.7071 - auc_1: 0.9555 - loss: 0.5752 - precision_1: 0.7734 - recall_1: 0.6435
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 7: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.7072 - auc_1: 0.9555 - loss: 0.5751 - precision_1: 0.7734 - recall_1: 0.6435 - val_accuracy: 0.7656 - val_auc_1: 0.9632 - val_loss: 0.6486 - val_precision_1: 0.8241 - val_recall_1: 0.6991 - learning_rate: 0.0010
# Epoch 8/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:51 689ms/step - accuracy: 0.7500 - auc_1: 0.9525 - loss: 0.8200 - precision_1: 0.8889 - recall_1: 0.7500
# Epoch 8: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7500 - auc_1: 0.9525 - loss: 0.4117 - precision_1: 0.8889 - recall_1: 0.7500 - val_accuracy: 0.5789 - val_auc_1: 0.9370 - val_loss: 0.4649 - val_precision_1: 0.6471 - val_recall_1: 0.5789 - learning_rate: 1.0000e-04
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.7361 - auc_1: 0.9617 - loss: 0.5227 - precision_1: 0.7996 - recall_1: 0.6803
# Epoch 9: val_loss did not improve from 0.31447
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.7361 - auc_1: 0.9617 - loss: 0.5227 - precision_1: 0.7996 - recall_1: 0.6803 - val_accuracy: 0.7359 - val_auc_1: 0.9583 - val_loss: 0.7019 - val_precision_1: 0.7908 - val_recall_1: 0.6689 - learning_rate: 1.0000e-04
# Epoch 10/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:45 664ms/step - accuracy: 0.6875 - auc_1: 0.9508 - loss: 0.5141 - precision_1: 0.8000 - recall_1: 0.6250
# Epoch 10: val_loss improved from 0.31447 to 0.27427, saving model to run11/models\model_ResNet50_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6875 - auc_1: 0.9508 - loss: 0.2581 - precision_1: 0.8000 - recall_1: 0.6250 - val_accuracy: 0.7368 - val_auc_1: 0.9728 - val_loss: 0.2743 - val_precision_1: 0.8235 - val_recall_1: 0.7368 - learning_rate: 1.0000e-04
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.7221 - auc_1: 0.9606 - loss: 0.5241 - precision_1: 0.7802 - recall_1: 0.6586
# Epoch 11: val_loss did not improve from 0.27427
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 877ms/step - accuracy: 0.7222 - auc_1: 0.9607 - loss: 0.5241 - precision_1: 0.7802 - recall_1: 0.6586 - val_accuracy: 0.7324 - val_auc_1: 0.9583 - val_loss: 0.6994 - val_precision_1: 0.7981 - val_recall_1: 0.6653 - learning_rate: 1.0000e-04
# Epoch 12/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:53 698ms/step - accuracy: 0.8438 - auc_1: 0.9770 - loss: 0.3166 - precision_1: 0.8077 - recall_1: 0.6562
# Epoch 12: val_loss did not improve from 0.27427
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8438 - auc_1: 0.9770 - loss: 0.1589 - precision_1: 0.8077 - recall_1: 0.6562 - val_accuracy: 0.4737 - val_auc_1: 0.9197 - val_loss: 0.4717 - val_precision_1: 0.5625 - val_recall_1: 0.4737 - learning_rate: 1.0000e-04
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.7341 - auc_1: 0.9621 - loss: 0.5373 - precision_1: 0.7947 - recall_1: 0.6731
# Epoch 13: val_loss did not improve from 0.27427
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 878ms/step - accuracy: 0.7341 - auc_1: 0.9621 - loss: 0.5372 - precision_1: 0.7947 - recall_1: 0.6731 - val_accuracy: 0.7056 - val_auc_1: 0.9553 - val_loss: 0.7252 - val_precision_1: 0.7714 - val_recall_1: 0.6497 - learning_rate: 1.0000e-04
# Epoch 14/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:47 675ms/step - accuracy: 0.7500 - auc_1: 0.9785 - loss: 0.3027 - precision_1: 0.8214 - recall_1: 0.7188
# Epoch 14: val_loss improved from 0.27427 to 0.14206, saving model to run11/models\model_ResNet50_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7500 - auc_1: 0.9785 - loss: 0.1519 - precision_1: 0.8214 - recall_1: 0.7188 - val_accuracy: 0.8947 - val_auc_1: 0.9935 - val_loss: 0.1421 - val_precision_1: 0.9412 - val_recall_1: 0.8421 - learning_rate: 1.0000e-04
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - accuracy: 0.7332 - auc_1: 0.9602 - loss: 0.4960 - precision_1: 0.7970 - recall_1: 0.6677
# Epoch 15: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.7332 - auc_1: 0.9602 - loss: 0.4960 - precision_1: 0.7970 - recall_1: 0.6678 - val_accuracy: 0.7263 - val_auc_1: 0.9593 - val_loss: 0.6896 - val_precision_1: 0.7894 - val_recall_1: 0.6709 - learning_rate: 1.0000e-04
# Epoch 16/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:46 669ms/step - accuracy: 0.6875 - auc_1: 0.9547 - loss: 0.4597 - precision_1: 0.7000 - recall_1: 0.6562
# Epoch 16: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.6875 - auc_1: 0.9547 - loss: 0.2308 - precision_1: 0.7000 - recall_1: 0.6562 - val_accuracy: 0.6842 - val_auc_1: 0.9531 - val_loss: 0.3675 - val_precision_1: 0.7647 - val_recall_1: 0.6842 - learning_rate: 1.0000e-04
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.7379 - auc_1: 0.9625 - loss: 0.4697 - precision_1: 0.7992 - recall_1: 0.6741
# Epoch 17: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 879ms/step - accuracy: 0.7378 - auc_1: 0.9625 - loss: 0.4698 - precision_1: 0.7992 - recall_1: 0.6741 - val_accuracy: 0.7193 - val_auc_1: 0.9570 - val_loss: 0.7098 - val_precision_1: 0.7914 - val_recall_1: 0.6557 - learning_rate: 1.0000e-04
# Epoch 18/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:57 713ms/step - accuracy: 0.6875 - auc_1: 0.9445 - loss: 0.4756 - precision_1: 0.7083 - recall_1: 0.5312
# Epoch 18: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6875 - auc_1: 0.9445 - loss: 0.2388 - precision_1: 0.7083 - recall_1: 0.5312 - val_accuracy: 0.8421 - val_auc_1: 0.9721 - val_loss: 0.2950 - val_precision_1: 0.8750 - val_recall_1: 0.7368 - learning_rate: 1.0000e-04
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.7368 - auc_1: 0.9610 - loss: 0.4827 - precision_1: 0.7957 - recall_1: 0.6793
# Epoch 19: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 19: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 879ms/step - accuracy: 0.7368 - auc_1: 0.9610 - loss: 0.4827 - precision_1: 0.7957 - recall_1: 0.6792 - val_accuracy: 0.7182 - val_auc_1: 0.9574 - val_loss: 0.7075 - val_precision_1: 0.7841 - val_recall_1: 0.6552 - learning_rate: 1.0000e-04
# Epoch 20/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:49 682ms/step - accuracy: 0.6875 - auc_1: 0.9464 - loss: 0.6715 - precision_1: 0.7600 - recall_1: 0.5938
# Epoch 20: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.6875 - auc_1: 0.9464 - loss: 0.3371 - precision_1: 0.7600 - recall_1: 0.5938 - val_accuracy: 0.7895 - val_auc_1: 0.9834 - val_loss: 0.2368 - val_precision_1: 0.8667 - val_recall_1: 0.6842 - learning_rate: 1.0000e-05
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - accuracy: 0.7379 - auc_1: 0.9630 - loss: 0.4772 - precision_1: 0.7994 - recall_1: 0.6734
# Epoch 21: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 219s 875ms/step - accuracy: 0.7379 - auc_1: 0.9630 - loss: 0.4772 - precision_1: 0.7994 - recall_1: 0.6734 - val_accuracy: 0.7198 - val_auc_1: 0.9574 - val_loss: 0.7054 - val_precision_1: 0.7846 - val_recall_1: 0.6573 - learning_rate: 1.0000e-05
# Epoch 22/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:46 671ms/step - accuracy: 0.7188 - auc_1: 0.9530 - loss: 0.3115 - precision_1: 0.8000 - recall_1: 0.6250
# Epoch 22: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.7188 - auc_1: 0.9530 - loss: 0.1564 - precision_1: 0.8000 - recall_1: 0.6250 - val_accuracy: 0.6316 - val_auc_1: 0.9550 - val_loss: 0.3450 - val_precision_1: 0.6667 - val_recall_1: 0.5263 - learning_rate: 1.0000e-05
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - accuracy: 0.7384 - auc_1: 0.9641 - loss: 0.4833 - precision_1: 0.7940 - recall_1: 0.6716
# Epoch 23: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 220s 876ms/step - accuracy: 0.7384 - auc_1: 0.9641 - loss: 0.4834 - precision_1: 0.7940 - recall_1: 0.6716 - val_accuracy: 0.7208 - val_auc_1: 0.9578 - val_loss: 0.7035 - val_precision_1: 0.7838 - val_recall_1: 0.6578 - learning_rate: 1.0000e-05
# Epoch 24/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:48 678ms/step - accuracy: 0.5625 - auc_1: 0.9475 - loss: 0.3699 - precision_1: 0.7500 - recall_1: 0.5625
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 24: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.5625 - auc_1: 0.9475 - loss: 0.1857 - precision_1: 0.7500 - recall_1: 0.5625 - val_accuracy: 0.6842 - val_auc_1: 0.9684 - val_loss: 0.3025 - val_precision_1: 0.9286 - val_recall_1: 0.6842 - learning_rate: 1.0000e-05
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.7382 - auc_1: 0.9632 - loss: 0.5141 - precision_1: 0.7999 - recall_1: 0.6690
# Epoch 25: val_loss did not improve from 0.14206
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 221s 879ms/step - accuracy: 0.7382 - auc_1: 0.9632 - loss: 0.5141 - precision_1: 0.7999 - recall_1: 0.6690 - val_accuracy: 0.7223 - val_auc_1: 0.9580 - val_loss: 0.7023 - val_precision_1: 0.7878 - val_recall_1: 0.6588 - learning_rate: 1.0000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 44s 691ms/step - accuracy: 0.7108 - auc_1: 0.9543 - loss: 0.7383 - precision_1: 0.7782 - recall_1: 0.6509
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: ResNet50, Optimizer: SGD
# Validation Loss: 0.7031
# Validation Accuracy: 0.7219
# Validation Precision: 0.9581
# Validation Recall: 0.7875
# Validation AUC-ROC: 0.6585
# [ 4.36859324  2.78484532  1.30212904 12.44099379  1.28603531  0.21338021
#  10.04010025]
# {0: 4.368593238822246, 1: 2.7848453249913105, 2: 1.3021290427433772, 3: 12.440993788819876, 4: 1.2860353130016051, 5: 0.21338020666879728, 6: 10.040100250626567}
# Found 8012 images belonging to 7 classes.
# Found 2003 images belonging to 7 classes.
# Epoch 1/25
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3140 - auc_2: 0.6997 - loss: 3.2511 - precision_2: 0.3382 - recall_2: 0.2630
# Epoch 1: val_loss improved from inf to 1.54822, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 523s 2s/step - accuracy: 0.3143 - auc_2: 0.7000 - loss: 3.2478 - precision_2: 0.3386 - recall_2: 0.2632 - val_accuracy: 0.4461 - val_auc_2: 0.8128 - val_loss: 1.5482 - val_precision_2: 0.5548 - val_recall_2: 0.3059 - learning_rate: 0.0010
# Epoch 2/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:53 2s/step - accuracy: 0.3438 - auc_2: 0.7513 - loss: 0.9993 - precision_2: 0.4286 - recall_2: 0.2812
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss improved from 1.54822 to 0.66328, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.3438 - auc_2: 0.7513 - loss: 0.5016 - precision_2: 0.4286 - recall_2: 0.2812 - val_accuracy: 0.4737 - val_auc_2: 0.8534 - val_loss: 0.6633 - val_precision_2: 0.6667 - val_recall_2: 0.4211 - learning_rate: 0.0010
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5007 - auc_2: 0.8381 - loss: 1.3447 - precision_2: 0.5859 - recall_2: 0.3886
# Epoch 3: val_loss did not improve from 0.66328
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.5007 - auc_2: 0.8382 - loss: 1.3447 - precision_2: 0.5860 - recall_2: 0.3886 - val_accuracy: 0.4834 - val_auc_2: 0.8517 - val_loss: 1.3489 - val_precision_2: 0.5949 - val_recall_2: 0.3649 - learning_rate: 0.0010
# Epoch 4/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 7:01 2s/step - accuracy: 0.5312 - auc_2: 0.8354 - loss: 1.0815 - precision_2: 0.6087 - recall_2: 0.4375
# Epoch 4: val_loss improved from 0.66328 to 0.58714, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5312 - auc_2: 0.8354 - loss: 0.5429 - precision_2: 0.6087 - recall_2: 0.4375 - val_accuracy: 0.4211 - val_auc_2: 0.8848 - val_loss: 0.5871 - val_precision_2: 0.6154 - val_recall_2: 0.4211 - learning_rate: 0.0010
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5627 - auc_2: 0.8831 - loss: 1.1580 - precision_2: 0.6732 - recall_2: 0.4480
# Epoch 5: val_loss did not improve from 0.58714
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 537s 2s/step - accuracy: 0.5626 - auc_2: 0.8831 - loss: 1.1581 - precision_2: 0.6731 - recall_2: 0.4479 - val_accuracy: 0.4924 - val_auc_2: 0.8577 - val_loss: 1.3410 - val_precision_2: 0.5654 - val_recall_2: 0.3553 - learning_rate: 0.0010
# Epoch 6/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 7:32 2s/step - accuracy: 0.4688 - auc_2: 0.8333 - loss: 1.6513 - precision_2: 0.5000 - recall_2: 0.3438
# Epoch 6: val_loss improved from 0.58714 to 0.48208, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4688 - auc_2: 0.8333 - loss: 0.8290 - precision_2: 0.5000 - recall_2: 0.3438 - val_accuracy: 0.6842 - val_auc_2: 0.9303 - val_loss: 0.4821 - val_precision_2: 0.8000 - val_recall_2: 0.4211 - learning_rate: 0.0010
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5507 - auc_2: 0.8792 - loss: 1.0791 - precision_2: 0.6511 - recall_2: 0.4385
# Epoch 7: val_loss did not improve from 0.48208
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 529s 2s/step - accuracy: 0.5507 - auc_2: 0.8793 - loss: 1.0791 - precision_2: 0.6511 - recall_2: 0.4386 - val_accuracy: 0.5751 - val_auc_2: 0.9019 - val_loss: 1.0895 - val_precision_2: 0.7101 - val_recall_2: 0.4506 - learning_rate: 0.0010
# Epoch 8/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:53 2s/step - accuracy: 0.3750 - auc_2: 0.8067 - loss: 1.3436 - precision_2: 0.4211 - recall_2: 0.2500
# Epoch 8: val_loss improved from 0.48208 to 0.42185, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.3750 - auc_2: 0.8067 - loss: 0.6745 - precision_2: 0.4211 - recall_2: 0.2500 - val_accuracy: 0.6842 - val_auc_2: 0.9432 - val_loss: 0.4219 - val_precision_2: 0.8182 - val_recall_2: 0.4737 - learning_rate: 0.0010
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5881 - auc_2: 0.9030 - loss: 0.9969 - precision_2: 0.7090 - recall_2: 0.4768
# Epoch 9: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 522s 2s/step - accuracy: 0.5881 - auc_2: 0.9030 - loss: 0.9968 - precision_2: 0.7090 - recall_2: 0.4768 - val_accuracy: 0.6200 - val_auc_2: 0.9122 - val_loss: 1.0548 - val_precision_2: 0.7172 - val_recall_2: 0.5176 - learning_rate: 0.0010
# Epoch 10/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 7:16 2s/step - accuracy: 0.5000 - auc_2: 0.8733 - loss: 1.0260 - precision_2: 0.6250 - recall_2: 0.4688
# Epoch 10: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5000 - auc_2: 0.8733 - loss: 0.5150 - precision_2: 0.6250 - recall_2: 0.4688 - val_accuracy: 0.6842 - val_auc_2: 0.9301 - val_loss: 0.4511 - val_precision_2: 0.8571 - val_recall_2: 0.6316 - learning_rate: 0.0010
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6044 - auc_2: 0.9009 - loss: 0.9383 - precision_2: 0.6908 - recall_2: 0.5061
# Epoch 11: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 521s 2s/step - accuracy: 0.6044 - auc_2: 0.9009 - loss: 0.9384 - precision_2: 0.6908 - recall_2: 0.5061 - val_accuracy: 0.6396 - val_auc_2: 0.9130 - val_loss: 1.0278 - val_precision_2: 0.7446 - val_recall_2: 0.5202 - learning_rate: 0.0010
# Epoch 12/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:56 2s/step - accuracy: 0.5312 - auc_2: 0.8896 - loss: 1.2222 - precision_2: 0.6364 - recall_2: 0.4375
# Epoch 12: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5312 - auc_2: 0.8896 - loss: 0.6136 - precision_2: 0.6364 - recall_2: 0.4375 - val_accuracy: 0.6842 - val_auc_2: 0.9137 - val_loss: 0.5082 - val_precision_2: 0.7857 - val_recall_2: 0.5789 - learning_rate: 0.0010
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6266 - auc_2: 0.9183 - loss: 0.8938 - precision_2: 0.7147 - recall_2: 0.5407
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 13: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.6265 - auc_2: 0.9182 - loss: 0.8940 - precision_2: 0.7146 - recall_2: 0.5406 - val_accuracy: 0.6154 - val_auc_2: 0.9247 - val_loss: 0.9510 - val_precision_2: 0.7237 - val_recall_2: 0.5055 - learning_rate: 0.0010
# Epoch 14/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:58 2s/step - accuracy: 0.5312 - auc_2: 0.8954 - loss: 0.8625 - precision_2: 0.5417 - recall_2: 0.4062
# Epoch 14: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5312 - auc_2: 0.8954 - loss: 0.4330 - precision_2: 0.5417 - recall_2: 0.4062 - val_accuracy: 0.6316 - val_auc_2: 0.9386 - val_loss: 0.4247 - val_precision_2: 0.8462 - val_recall_2: 0.5789 - learning_rate: 1.0000e-04
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6279 - auc_2: 0.9224 - loss: 0.8185 - precision_2: 0.7344 - recall_2: 0.5318
# Epoch 15: val_loss did not improve from 0.42185
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 519s 2s/step - accuracy: 0.6280 - auc_2: 0.9225 - loss: 0.8181 - precision_2: 0.7345 - recall_2: 0.5319 - val_accuracy: 0.6699 - val_auc_2: 0.9419 - val_loss: 0.8318 - val_precision_2: 0.7895 - val_recall_2: 0.5746 - learning_rate: 1.0000e-04
# Epoch 16/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:47 2s/step - accuracy: 0.5000 - auc_2: 0.8743 - loss: 0.6125 - precision_2: 0.6316 - recall_2: 0.3750
# Epoch 16: val_loss improved from 0.42185 to 0.28036, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5000 - auc_2: 0.8743 - loss: 0.3075 - precision_2: 0.6316 - recall_2: 0.3750 - val_accuracy: 0.7368 - val_auc_2: 0.9758 - val_loss: 0.2804 - val_precision_2: 0.8667 - val_recall_2: 0.6842 - learning_rate: 1.0000e-04
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6782 - auc_2: 0.9407 - loss: 0.6594 - precision_2: 0.7739 - recall_2: 0.5847
# Epoch 17: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.6782 - auc_2: 0.9407 - loss: 0.6594 - precision_2: 0.7739 - recall_2: 0.5847 - val_accuracy: 0.6840 - val_auc_2: 0.9442 - val_loss: 0.8145 - val_precision_2: 0.7879 - val_recall_2: 0.5897 - learning_rate: 1.0000e-04
# Epoch 18/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:44 2s/step - accuracy: 0.7500 - auc_2: 0.9679 - loss: 0.5637 - precision_2: 0.9200 - recall_2: 0.7188
# Epoch 18: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7500 - auc_2: 0.9679 - loss: 0.2830 - precision_2: 0.9200 - recall_2: 0.7188 - val_accuracy: 0.7368 - val_auc_2: 0.9271 - val_loss: 0.4379 - val_precision_2: 0.8000 - val_recall_2: 0.6316 - learning_rate: 1.0000e-04
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6994 - auc_2: 0.9490 - loss: 0.6408 - precision_2: 0.7983 - recall_2: 0.6072
# Epoch 19: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.6994 - auc_2: 0.9490 - loss: 0.6407 - precision_2: 0.7983 - recall_2: 0.6071 - val_accuracy: 0.6815 - val_auc_2: 0.9454 - val_loss: 0.8036 - val_precision_2: 0.7806 - val_recall_2: 0.5988 - learning_rate: 1.0000e-04
# Epoch 20/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:51 2s/step - accuracy: 0.5938 - auc_2: 0.9261 - loss: 0.4794 - precision_2: 0.6538 - recall_2: 0.5312
# Epoch 20: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5938 - auc_2: 0.9261 - loss: 0.2406 - precision_2: 0.6538 - recall_2: 0.5312 - val_accuracy: 0.6842 - val_auc_2: 0.9391 - val_loss: 0.4214 - val_precision_2: 0.8000 - val_recall_2: 0.6316 - learning_rate: 1.0000e-04
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7062 - auc_2: 0.9505 - loss: 0.5972 - precision_2: 0.7902 - recall_2: 0.6226
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 21: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.7061 - auc_2: 0.9505 - loss: 0.5972 - precision_2: 0.7901 - recall_2: 0.6226 - val_accuracy: 0.6769 - val_auc_2: 0.9434 - val_loss: 0.8202 - val_precision_2: 0.7763 - val_recall_2: 0.5983 - learning_rate: 1.0000e-04
# Epoch 22/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 7:18 2s/step - accuracy: 0.7188 - auc_2: 0.9611 - loss: 0.7023 - precision_2: 0.8000 - recall_2: 0.6250
# Epoch 22: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7188 - auc_2: 0.9611 - loss: 0.3526 - precision_2: 0.8000 - recall_2: 0.6250 - val_accuracy: 0.6316 - val_auc_2: 0.9524 - val_loss: 0.3806 - val_precision_2: 0.7857 - val_recall_2: 0.5789 - learning_rate: 1.0000e-05
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6918 - auc_2: 0.9477 - loss: 0.5917 - precision_2: 0.7912 - recall_2: 0.6201
# Epoch 23: val_loss did not improve from 0.28036
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 521s 2s/step - accuracy: 0.6918 - auc_2: 0.9477 - loss: 0.5917 - precision_2: 0.7912 - recall_2: 0.6201 - val_accuracy: 0.6804 - val_auc_2: 0.9447 - val_loss: 0.8094 - val_precision_2: 0.7771 - val_recall_2: 0.6008 - learning_rate: 1.0000e-05
# Epoch 24/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:59 2s/step - accuracy: 0.6562 - auc_2: 0.9429 - loss: 0.5962 - precision_2: 0.7143 - recall_2: 0.6250
# Epoch 24: val_loss improved from 0.28036 to 0.27796, saving model to run11/models\model_VGG16_Adam.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.6562 - auc_2: 0.9429 - loss: 0.2993 - precision_2: 0.7143 - recall_2: 0.6250 - val_accuracy: 0.7368 - val_auc_2: 0.9799 - val_loss: 0.2780 - val_precision_2: 0.9231 - val_recall_2: 0.6316 - learning_rate: 1.0000e-05
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7118 - auc_2: 0.9515 - loss: 0.5688 - precision_2: 0.7987 - recall_2: 0.6228
# Epoch 25: val_loss did not improve from 0.27796
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 521s 2s/step - accuracy: 0.7118 - auc_2: 0.9515 - loss: 0.5688 - precision_2: 0.7987 - recall_2: 0.6227 - val_accuracy: 0.6825 - val_auc_2: 0.9465 - val_loss: 0.7973 - val_precision_2: 0.7803 - val_recall_2: 0.6033 - learning_rate: 1.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6928 - auc_2: 0.9501 - loss: 0.7688 - precision_2: 0.7923 - recall_2: 0.6133
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: VGG16, Optimizer: Adam
# Validation Loss: 0.7969
# Validation Accuracy: 0.6830
# Validation Precision: 0.9465
# Validation Recall: 0.7795
# Validation AUC-ROC: 0.6036
# [ 4.36859324  2.78484532  1.30212904 12.44099379  1.28603531  0.21338021
#  10.04010025]
# {0: 4.368593238822246, 1: 2.7848453249913105, 2: 1.3021290427433772, 3: 12.440993788819876, 4: 1.2860353130016051, 5: 0.21338020666879728, 6: 10.040100250626567}
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6885 - auc_3: 0.9442 - loss: 0.6326 - precision_3: 0.7765 - recall_3: 0.6087
# Epoch 1: val_loss improved from inf to 0.77421, saving model to run11/models\model_VGG16_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 522s 2s/step - accuracy: 0.6885 - auc_3: 0.9442 - loss: 0.6328 - precision_3: 0.7764 - recall_3: 0.6086 - val_accuracy: 0.7288 - val_auc_3: 0.9500 - val_loss: 0.7742 - val_precision_3: 0.8254 - val_recall_3: 0.6386 - learning_rate: 0.0010
# Epoch 2/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:51 2s/step - accuracy: 0.7812 - auc_3: 0.9734 - loss: 0.3471 - precision_3: 0.8571 - recall_3: 0.7500
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss improved from 0.77421 to 0.53012, saving model to run11/models\model_VGG16_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7812 - auc_3: 0.9734 - loss: 0.1742 - precision_3: 0.8571 - recall_3: 0.7500 - val_accuracy: 0.7895 - val_auc_3: 0.9335 - val_loss: 0.5301 - val_precision_3: 0.8667 - val_recall_3: 0.6842 - learning_rate: 0.0010
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6792 - auc_3: 0.9411 - loss: 0.6496 - precision_3: 0.7703 - recall_3: 0.6047
# Epoch 3: val_loss did not improve from 0.53012
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.6792 - auc_3: 0.9411 - loss: 0.6496 - precision_3: 0.7703 - recall_3: 0.6047 - val_accuracy: 0.6951 - val_auc_3: 0.9455 - val_loss: 0.8154 - val_precision_3: 0.7676 - val_recall_3: 0.6260 - learning_rate: 0.0010
# Epoch 4/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:54 2s/step - accuracy: 0.7812 - auc_3: 0.9587 - loss: 0.4186 - precision_3: 0.8519 - recall_3: 0.7188
# Epoch 4: val_loss improved from 0.53012 to 0.38670, saving model to run11/models\model_VGG16_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7812 - auc_3: 0.9587 - loss: 0.2101 - precision_3: 0.8519 - recall_3: 0.7188 - val_accuracy: 0.6842 - val_auc_3: 0.9541 - val_loss: 0.3867 - val_precision_3: 0.8333 - val_recall_3: 0.5263 - learning_rate: 0.0010
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6857 - auc_3: 0.9427 - loss: 0.6705 - precision_3: 0.7659 - recall_3: 0.6165
# Epoch 5: val_loss did not improve from 0.38670
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 519s 2s/step - accuracy: 0.6857 - auc_3: 0.9427 - loss: 0.6704 - precision_3: 0.7659 - recall_3: 0.6165 - val_accuracy: 0.6608 - val_auc_3: 0.9352 - val_loss: 0.8960 - val_precision_3: 0.7326 - val_recall_3: 0.5771 - learning_rate: 0.0010
# Epoch 6/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:55 2s/step - accuracy: 0.6250 - auc_3: 0.8972 - loss: 1.1339 - precision_3: 0.6667 - recall_3: 0.5000
# Epoch 6: val_loss improved from 0.38670 to 0.36924, saving model to run11/models\model_VGG16_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6250 - auc_3: 0.8972 - loss: 0.5692 - precision_3: 0.6667 - recall_3: 0.5000 - val_accuracy: 0.7368 - val_auc_3: 0.9506 - val_loss: 0.3692 - val_precision_3: 0.8125 - val_recall_3: 0.6842 - learning_rate: 0.0010
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6887 - auc_3: 0.9449 - loss: 0.6345 - precision_3: 0.7646 - recall_3: 0.6016
# Epoch 7: val_loss did not improve from 0.36924
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 520s 2s/step - accuracy: 0.6887 - auc_3: 0.9449 - loss: 0.6346 - precision_3: 0.7646 - recall_3: 0.6017 - val_accuracy: 0.6734 - val_auc_3: 0.9373 - val_loss: 0.8693 - val_precision_3: 0.7603 - val_recall_3: 0.5837 - learning_rate: 0.0010
# Epoch 8/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:48 2s/step - accuracy: 0.5312 - auc_3: 0.9150 - loss: 0.7115 - precision_3: 0.6667 - recall_3: 0.5000
# Epoch 8: val_loss improved from 0.36924 to 0.31408, saving model to run11/models\model_VGG16_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5312 - auc_3: 0.9150 - loss: 0.3572 - precision_3: 0.6667 - recall_3: 0.5000 - val_accuracy: 0.8421 - val_auc_3: 0.9730 - val_loss: 0.3141 - val_precision_3: 0.8571 - val_recall_3: 0.6316 - learning_rate: 0.0010
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6974 - auc_3: 0.9461 - loss: 0.5873 - precision_3: 0.7703 - recall_3: 0.6210
# Epoch 9: val_loss did not improve from 0.31408
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 521s 2s/step - accuracy: 0.6974 - auc_3: 0.9462 - loss: 0.5874 - precision_3: 0.7704 - recall_3: 0.6210 - val_accuracy: 0.7041 - val_auc_3: 0.9498 - val_loss: 0.7754 - val_precision_3: 0.7676 - val_recall_3: 0.6326 - learning_rate: 0.0010
# Epoch 10/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:49 2s/step - accuracy: 0.7500 - auc_3: 0.9762 - loss: 0.4074 - precision_3: 0.8519 - recall_3: 0.7188
# Epoch 10: val_loss did not improve from 0.31408
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7500 - auc_3: 0.9762 - loss: 0.2045 - precision_3: 0.8519 - recall_3: 0.7188 - val_accuracy: 0.5789 - val_auc_3: 0.9206 - val_loss: 0.5170 - val_precision_3: 0.5882 - val_recall_3: 0.5263 - learning_rate: 0.0010
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7080 - auc_3: 0.9502 - loss: 0.5626 - precision_3: 0.7803 - recall_3: 0.6414
# Epoch 11: val_loss did not improve from 0.31408
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 521s 2s/step - accuracy: 0.7080 - auc_3: 0.9502 - loss: 0.5627 - precision_3: 0.7802 - recall_3: 0.6413 - val_accuracy: 0.7056 - val_auc_3: 0.9483 - val_loss: 0.7863 - val_precision_3: 0.7764 - val_recall_3: 0.6300 - learning_rate: 0.0010
# Epoch 12/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 6:56 2s/step - accuracy: 0.6562 - auc_3: 0.9135 - loss: 0.4479 - precision_3: 0.8261 - recall_3: 0.5938
# Epoch 12: val_loss did not improve from 0.31408
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6562 - auc_3: 0.9135 - loss: 0.2249 - precision_3: 0.8261 - recall_3: 0.5938 - val_accuracy: 0.6316 - val_auc_3: 0.9307 - val_loss: 0.4824 - val_precision_3: 0.7059 - val_recall_3: 0.6316 - learning_rate: 0.0010
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7017 - auc_3: 0.9530 - loss: 0.5662 - precision_3: 0.7794 - recall_3: 0.6402
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 13: val_loss did not improve from 0.31408
# ...
# Epoch 23: val_loss did not improve from 0.28732
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6372 - auc_4: 0.9224 - loss: 0.8128 - precision_4: 0.7624 - recall_4: 0.5171 - val_accuracy: 0.6406 - val_auc_4: 0.9196 - val_loss: 0.9760 - val_precision_4: 0.7494 - val_recall_4: 0.4990 - learning_rate: 1.0000e-04
# Epoch 24/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 788ms/step - accuracy: 0.5000 - auc_4: 0.8914 - loss: 0.9694 - precision_4: 0.6000 - recall_4: 0.3750
# Epoch 24: val_loss did not improve from 0.28732
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5000 - auc_4: 0.8914 - loss: 0.4866 - precision_4: 0.6000 - recall_4: 0.3750 - val_accuracy: 0.4737 - val_auc_4: 0.8066 - val_loss: 0.7946 - val_precision_4: 0.4286 - val_recall_4: 0.3158 - learning_rate: 1.0000e-04
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 801ms/step - accuracy: 0.6405 - auc_4: 0.9229 - loss: 0.8057 - precision_4: 0.7638 - recall_4: 0.5163
# Epoch 25: val_loss did not improve from 0.28732
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 253s 1s/step - accuracy: 0.6405 - auc_4: 0.9229 - loss: 0.8057 - precision_4: 0.7638 - recall_4: 0.5163 - val_accuracy: 0.6517 - val_auc_4: 0.9280 - val_loss: 0.9253 - val_precision_4: 0.7726 - val_recall_4: 0.5257 - learning_rate: 1.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 50s 796ms/step - accuracy: 0.6479 - auc_4: 0.9250 - loss: 0.9421 - precision_4: 0.7565 - recall_4: 0.5108
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: InceptionV3, Optimizer: Adam
# Validation Loss: 0.9248
# Validation Accuracy: 0.6520
# Validation Precision: 0.9281
# Validation Recall: 0.7731
# Validation AUC-ROC: 0.5257
# [ 4.36859324  2.78484532  1.30212904 12.44099379  1.28603531  0.21338021
#  10.04010025]
# {0: 4.368593238822246, 1: 2.7848453249913105, 2: 1.3021290427433772, 3: 12.440993788819876, 4: 1.2860353130016051, 5: 0.21338020666879728, 6: 10.040100250626567}
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - accuracy: 0.6495 - auc_5: 0.9284 - loss: 0.8081 - precision_5: 0.7533 - recall_5: 0.5290
# Epoch 1: val_loss improved from inf to 0.95981, saving model to run11/models\model_InceptionV3_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 259s 1s/step - accuracy: 0.6495 - auc_5: 0.9284 - loss: 0.8081 - precision_5: 0.7533 - recall_5: 0.5290 - val_accuracy: 0.6457 - val_auc_5: 0.9225 - val_loss: 0.9598 - val_precision_5: 0.7498 - val_recall_5: 0.5091 - learning_rate: 0.0010
# Epoch 2/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:22 814ms/step - accuracy: 0.5312 - auc_5: 0.9264 - loss: 0.7180 - precision_5: 0.8000 - recall_5: 0.5000
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\contextlib.py:137: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_loss improved from 0.95981 to 0.47323, saving model to run11/models\model_InceptionV3_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.5312 - auc_5: 0.9264 - loss: 0.3604 - precision_5: 0.8000 - recall_5: 0.5000 - val_accuracy: 0.5789 - val_auc_5: 0.9303 - val_loss: 0.4732 - val_precision_5: 0.6154 - val_recall_5: 0.4211 - learning_rate: 0.0010
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.6444 - auc_5: 0.9278 - loss: 0.7749 - precision_5: 0.7566 - recall_5: 0.5277
# Epoch 3: val_loss did not improve from 0.47323
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6444 - auc_5: 0.9278 - loss: 0.7750 - precision_5: 0.7566 - recall_5: 0.5277 - val_accuracy: 0.6472 - val_auc_5: 0.9256 - val_loss: 0.9390 - val_precision_5: 0.7591 - val_recall_5: 0.5161 - learning_rate: 0.0010
# Epoch 4/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:17 793ms/step - accuracy: 0.6562 - auc_5: 0.9443 - loss: 0.6644 - precision_5: 0.7500 - recall_5: 0.4688
# Epoch 4: val_loss did not improve from 0.47323
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6562 - auc_5: 0.9443 - loss: 0.3335 - precision_5: 0.7500 - recall_5: 0.4688 - val_accuracy: 0.6316 - val_auc_5: 0.9116 - val_loss: 0.5092 - val_precision_5: 0.7500 - val_recall_5: 0.4737 - learning_rate: 0.0010
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6366 - auc_5: 0.9253 - loss: 0.7940 - precision_5: 0.7432 - recall_5: 0.5276
# Epoch 5: val_loss did not improve from 0.47323
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6366 - auc_5: 0.9253 - loss: 0.7939 - precision_5: 0.7432 - recall_5: 0.5276 - val_accuracy: 0.6467 - val_auc_5: 0.9266 - val_loss: 0.9359 - val_precision_5: 0.7539 - val_recall_5: 0.5418 - learning_rate: 0.0010
# Epoch 6/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 790ms/step - accuracy: 0.5625 - auc_5: 0.8982 - loss: 1.1076 - precision_5: 0.7368 - recall_5: 0.4375
# Epoch 6: val_loss improved from 0.47323 to 0.36187, saving model to run11/models\model_InceptionV3_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.5625 - auc_5: 0.8982 - loss: 0.5560 - precision_5: 0.7368 - recall_5: 0.4375 - val_accuracy: 0.6842 - val_auc_5: 0.9578 - val_loss: 0.3619 - val_precision_5: 0.7500 - val_recall_5: 0.6316 - learning_rate: 0.0010
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6577 - auc_5: 0.9348 - loss: 0.7169 - precision_5: 0.7539 - recall_5: 0.5657
# Epoch 7: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6576 - auc_5: 0.9348 - loss: 0.7170 - precision_5: 0.7539 - recall_5: 0.5656 - val_accuracy: 0.6653 - val_auc_5: 0.9315 - val_loss: 0.9043 - val_precision_5: 0.7672 - val_recall_5: 0.5565 - learning_rate: 0.0010
# Epoch 8/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 783ms/step - accuracy: 0.5312 - auc_5: 0.8792 - loss: 1.2236 - precision_5: 0.6818 - recall_5: 0.4688
# Epoch 8: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5312 - auc_5: 0.8792 - loss: 0.6142 - precision_5: 0.6818 - recall_5: 0.4688 - val_accuracy: 0.5263 - val_auc_5: 0.8772 - val_loss: 0.5818 - val_precision_5: 0.7000 - val_recall_5: 0.3684 - learning_rate: 0.0010
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - accuracy: 0.6527 - auc_5: 0.9334 - loss: 0.7351 - precision_5: 0.7544 - recall_5: 0.5526
# Epoch 9: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6527 - auc_5: 0.9334 - loss: 0.7350 - precision_5: 0.7543 - recall_5: 0.5526 - val_accuracy: 0.6547 - val_auc_5: 0.9308 - val_loss: 0.9102 - val_precision_5: 0.7658 - val_recall_5: 0.5570 - learning_rate: 0.0010
# Epoch 10/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:14 782ms/step - accuracy: 0.4062 - auc_5: 0.8718 - loss: 0.8485 - precision_5: 0.5455 - recall_5: 0.3750
# Epoch 10: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.4062 - auc_5: 0.8718 - loss: 0.4260 - precision_5: 0.5455 - recall_5: 0.3750 - val_accuracy: 0.5789 - val_auc_5: 0.9047 - val_loss: 0.5179 - val_precision_5: 0.6667 - val_recall_5: 0.4211 - learning_rate: 0.0010
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6521 - auc_5: 0.9333 - loss: 0.7005 - precision_5: 0.7482 - recall_5: 0.5548
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 11: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6521 - auc_5: 0.9333 - loss: 0.7006 - precision_5: 0.7482 - recall_5: 0.5548 - val_accuracy: 0.6396 - val_auc_5: 0.9273 - val_loss: 0.9325 - val_precision_5: 0.7408 - val_recall_5: 0.5459 - learning_rate: 0.0010
# Epoch 12/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:15 785ms/step - accuracy: 0.6875 - auc_5: 0.9312 - loss: 0.4363 - precision_5: 0.7083 - recall_5: 0.5312
# Epoch 12: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc_5: 0.9312 - loss: 0.2190 - precision_5: 0.7083 - recall_5: 0.5312 - val_accuracy: 0.6316 - val_auc_5: 0.9164 - val_loss: 0.5072 - val_precision_5: 0.7143 - val_recall_5: 0.5263 - learning_rate: 1.0000e-04
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 804ms/step - accuracy: 0.6511 - auc_5: 0.9304 - loss: 0.7496 - precision_5: 0.7513 - recall_5: 0.5496
# Epoch 13: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.6511 - auc_5: 0.9304 - loss: 0.7494 - precision_5: 0.7513 - recall_5: 0.5496 - val_accuracy: 0.6653 - val_auc_5: 0.9367 - val_loss: 0.8689 - val_precision_5: 0.7659 - val_recall_5: 0.5721 - learning_rate: 1.0000e-04
# Epoch 14/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:18 799ms/step - accuracy: 0.7188 - auc_5: 0.9250 - loss: 0.8016 - precision_5: 0.8095 - recall_5: 0.5312
# Epoch 14: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7188 - auc_5: 0.9250 - loss: 0.4024 - precision_5: 0.8095 - recall_5: 0.5312 - val_accuracy: 0.6316 - val_auc_5: 0.9268 - val_loss: 0.4731 - val_precision_5: 0.7143 - val_recall_5: 0.5263 - learning_rate: 1.0000e-04
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.6596 - auc_5: 0.9351 - loss: 0.7048 - precision_5: 0.7540 - recall_5: 0.5583
# Epoch 15: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6596 - auc_5: 0.9351 - loss: 0.7047 - precision_5: 0.7541 - recall_5: 0.5583 - val_accuracy: 0.6694 - val_auc_5: 0.9360 - val_loss: 0.8732 - val_precision_5: 0.7703 - val_recall_5: 0.5680 - learning_rate: 1.0000e-04
# Epoch 16/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:17 794ms/step - accuracy: 0.6875 - auc_5: 0.9366 - loss: 0.5574 - precision_5: 0.7857 - recall_5: 0.6875
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 16: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc_5: 0.9366 - loss: 0.2798 - precision_5: 0.7857 - recall_5: 0.6875 - val_accuracy: 0.6842 - val_auc_5: 0.9324 - val_loss: 0.4646 - val_precision_5: 0.7857 - val_recall_5: 0.5789 - learning_rate: 1.0000e-04
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 811ms/step - accuracy: 0.6632 - auc_5: 0.9372 - loss: 0.6777 - precision_5: 0.7637 - recall_5: 0.5670
# Epoch 17: val_loss did not improve from 0.36187
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6632 - auc_5: 0.9372 - loss: 0.6777 - precision_5: 0.7637 - recall_5: 0.5670 - val_accuracy: 0.6714 - val_auc_5: 0.9362 - val_loss: 0.8723 - val_precision_5: 0.7703 - val_recall_5: 0.5696 - learning_rate: 1.0000e-05
# Epoch 18/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:22 814ms/step - accuracy: 0.6562 - auc_5: 0.9351 - loss: 0.5757 - precision_5: 0.7600 - recall_5: 0.5938
# Epoch 18: val_loss improved from 0.36187 to 0.34380, saving model to run11/models\model_InceptionV3_SGD.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.6562 - auc_5: 0.9351 - loss: 0.2890 - precision_5: 0.7600 - recall_5: 0.5938 - val_accuracy: 0.5263 - val_auc_5: 0.9536 - val_loss: 0.3438 - val_precision_5: 0.6923 - val_recall_5: 0.4737 - learning_rate: 1.0000e-05
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6838 - auc_5: 0.9423 - loss: 0.6807 - precision_5: 0.7809 - recall_5: 0.5774
# Epoch 19: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6838 - auc_5: 0.9423 - loss: 0.6807 - precision_5: 0.7809 - recall_5: 0.5773 - val_accuracy: 0.6683 - val_auc_5: 0.9366 - val_loss: 0.8699 - val_precision_5: 0.7680 - val_recall_5: 0.5691 - learning_rate: 1.0000e-05
# Epoch 20/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:25 827ms/step - accuracy: 0.6562 - auc_5: 0.9586 - loss: 0.6808 - precision_5: 0.8000 - recall_5: 0.6250
# Epoch 20: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6562 - auc_5: 0.9586 - loss: 0.3418 - precision_5: 0.8000 - recall_5: 0.6250 - val_accuracy: 0.6316 - val_auc_5: 0.9065 - val_loss: 0.5110 - val_precision_5: 0.9091 - val_recall_5: 0.5263 - learning_rate: 1.0000e-05
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6665 - auc_5: 0.9371 - loss: 0.6685 - precision_5: 0.7648 - recall_5: 0.5798
# Epoch 21: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6665 - auc_5: 0.9371 - loss: 0.6685 - precision_5: 0.7648 - recall_5: 0.5798 - val_accuracy: 0.6719 - val_auc_5: 0.9367 - val_loss: 0.8691 - val_precision_5: 0.7694 - val_recall_5: 0.5685 - learning_rate: 1.0000e-05
# Epoch 22/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:16 789ms/step - accuracy: 0.6875 - auc_5: 0.9390 - loss: 0.9004 - precision_5: 0.6538 - recall_5: 0.5312
# Epoch 22: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6875 - auc_5: 0.9390 - loss: 0.4520 - precision_5: 0.6538 - recall_5: 0.5312 - val_accuracy: 0.6316 - val_auc_5: 0.9462 - val_loss: 0.4141 - val_precision_5: 0.8462 - val_recall_5: 0.5789 - learning_rate: 1.0000e-05
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.6705 - auc_5: 0.9389 - loss: 0.6977 - precision_5: 0.7695 - recall_5: 0.5758
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
#
# Epoch 23: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 255s 1s/step - accuracy: 0.6705 - auc_5: 0.9389 - loss: 0.6977 - precision_5: 0.7695 - recall_5: 0.5758 - val_accuracy: 0.6704 - val_auc_5: 0.9366 - val_loss: 0.8695 - val_precision_5: 0.7698 - val_recall_5: 0.5696 - learning_rate: 1.0000e-05
# Epoch 24/25
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 3:17 795ms/step - accuracy: 0.7812 - auc_5: 0.9604 - loss: 0.5251 - precision_5: 0.9130 - recall_5: 0.6562
# Epoch 24: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7812 - auc_5: 0.9604 - loss: 0.2636 - precision_5: 0.9130 - recall_5: 0.6562 - val_accuracy: 0.6842 - val_auc_5: 0.9386 - val_loss: 0.4208 - val_precision_5: 0.9167 - val_recall_5: 0.5789 - learning_rate: 1.0000e-06
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 808ms/step - accuracy: 0.6735 - auc_5: 0.9380 - loss: 0.7043 - precision_5: 0.7641 - recall_5: 0.5725
# Epoch 25: val_loss did not improve from 0.34380
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 256s 1s/step - accuracy: 0.6735 - auc_5: 0.9380 - loss: 0.7042 - precision_5: 0.7641 - recall_5: 0.5725 - val_accuracy: 0.6694 - val_auc_5: 0.9361 - val_loss: 0.8730 - val_precision_5: 0.7698 - val_recall_5: 0.5680 - learning_rate: 1.0000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 51s 803ms/step - accuracy: 0.6808 - auc_5: 0.9367 - loss: 0.8732 - precision_5: 0.7741 - recall_5: 0.5726
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: InceptionV3, Optimizer: SGD
# Validation Loss: 0.8679
# Validation Accuracy: 0.6710
# Validation Precision: 0.9367
# Validation Recall: 0.7709
# Validation AUC-ROC: 0.5696
# [ 4.36859324  2.78484532  1.30212904 12.44099379  1.28603531  0.21338021
#  10.04010025]
# {0: 4.368593238822246, 1: 2.7848453249913105, 2: 1.3021290427433772, 3: 12.440993788819876, 4: 1.2860353130016051, 5: 0.21338020666879728, 6: 10.040100250626567}

# %% [markdown]
# # Evaluating and Visualizing the Data

# %%
# Importing Dependencies
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from tensorflow.keras.callbacks import TensorBoard, ReduceLROnPlateau
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import csv
import os

from sklearn.utils import class_weight
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
import numpy as np
import os

model_results = "model_results.csv"

# Run Number - use to create new directory or add to existing directory
run_number = 11
run_dir = f"run{run_number}"
os.makedirs(run_dir, exist_ok=True)


architectures = ["VGG16","ResNet50","InceptionV3"] # Options: "VGG16", "ResNet50", "InceptionV3"
optimizers = ["SGD","Adam"] # Options: "Adam", "RMSprop", "SGD"

batch_size = 32

# Define the preprocessing function based on the architectures you want to visualize
architectures_to_visualize = ["ResNet50"]  # Specify the architectures you want to visualize
preprocessing_functions = {
    "VGG16": tf.keras.applications.vgg16.preprocess_input,
    "ResNet50": tf.keras.applications.resnet50.preprocess_input,
    "InceptionV3": tf.keras.applications.inception_v3.preprocess_input
}


# Create a directory to store the visualization results
visualizations_dir = f"{run_dir}/visualizations"
os.makedirs(visualizations_dir, exist_ok=True)

#

# Iterate over each model architecture and optimizer
for architecture in architectures:
    # Set the preprocessing function based on the architecture
    preprocessing_function = preprocessing_functions[architecture]

    # Set the input shape and preprocessing function based on the selected architecture
    if architecture == "VGG16":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.vgg16.preprocess_input
    if architecture == "ResNet50":
        input_shape = (224, 224, 3)
        preprocessing_function = tf.keras.applications.resnet50.preprocess_input
    elif architecture == "InceptionV3":
        input_shape = (299, 299, 3)
        preprocessing_function = tf.keras.applications.inception_v3.preprocess_input

    # Redefine the validation dataset with the corresponding preprocessing function
    val_datagen = ImageDataGenerator(preprocessing_function=preprocessing_function)
    val_dataset = val_datagen.flow_from_directory(
        "Resources/Skin Cancer/val",
        target_size=input_shape[:2],
        batch_size=batch_size,
        class_mode="categorical",
    )

    # Get the class names from the redefined val_dataset
    class_names = list(val_dataset.class_indices.keys())


    for optimizer_name in optimizers:
        # Load the trained model
        model = load_model(os.path.join(f"{run_dir}/models/", f"model_{architecture}_{optimizer_name}.h5"))

        # Make predictions on the validation dataset using the redefined val_dataset
        y_pred = model.predict(val_dataset)
        y_pred_classes = np.argmax(y_pred, axis=1)

        # Get the true labels of the validation dataset
        y_true = val_dataset.classes

        # Compute the confusion matrix
        cm = confusion_matrix(y_true, y_pred_classes)
        print(f"Confusion Matrix for {architecture}_{optimizer_name}:")
        print(cm)

        # Save the confusion matrix as a CSV file
        cm_filename = f"confusion_matrix_{architecture}_{optimizer_name}.csv"
        np.savetxt(os.path.join(visualizations_dir, cm_filename), cm, delimiter=",")

        # Compute the classification report
        cr = classification_report(y_true, y_pred_classes, target_names=class_names)
        print(f"Classification Report for {architecture}_{optimizer_name}:")
        print(cr)

        # Save the classification report as a text file
        cr_filename = f"classification_report_{architecture}_{optimizer_name}.txt"
        with open(os.path.join(visualizations_dir, cr_filename), "w") as file:
            file.write(cr)

        # Compute the ROC curve and AUC for each class
        fpr = dict()
        tpr = dict()
        roc_auc = dict()
        for i in range(len(class_names)):
            fpr[i], tpr[i], _ = roc_curve(y_true == i, y_pred[:, i])
            roc_auc[i] = auc(fpr[i], tpr[i])

        # Plot the ROC curve for each class
        plt.figure(figsize=(8, 6))
        for i in range(len(class_names)):
            plt.plot(
                fpr[i],
                tpr[i],
                label=f"ROC curve of class {class_names[i]} (AUC = {roc_auc[i]:.2f})",
            )
        plt.plot([0, 1], [0, 1], "k--")
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve for {architecture}_{optimizer_name}")
        plt.legend(loc="lower right")
        plt.tight_layout()
        plt.savefig(os.path.join(visualizations_dir, f"roc_curve_{architecture}_{optimizer_name}.png"))
        plt.close()

        # Visualize the model's predictions on a subset of the validation data
        subset_size = 10
        subset_indices = np.random.choice(len(val_dataset), subset_size, replace=False)
        subset_images = []
        subset_labels = []
        val_dataset.reset()  # Reset the validation dataset iterator
        for i in range(len(val_dataset)):
            if i in subset_indices:
                image_batch, label_batch = next(val_dataset)
                for image, label in zip(image_batch, label_batch):
                    subset_images.append(image)
                    subset_labels.append(label)

        subset_images = np.array(subset_images)
        subset_labels = np.array(subset_labels)

        subset_preds = model.predict(subset_images)
        subset_pred_classes = np.argmax(subset_preds, axis=1)

        # Generate the visualization plot
        plt.figure(figsize=(15, 10))
        for i in range(subset_size):
            plt.subplot(2, 5, i + 1)
            plt.imshow(subset_images[i])
            plt.title(
                f"True: {class_names[np.argmax(subset_labels[i])]}\\nPred: {class_names[subset_pred_classes[i]]}"
            )
            plt.axis("off")
        plt.tight_layout()
        plt.savefig(os.path.join(visualizations_dir, f"predictions_{architecture}_{optimizer_name}.png"))
        plt.close()


# Read the CSV file and store the model results
model_results = []
with open("model_results.csv", "r") as file:
    csv_reader = csv.DictReader(file)
    for row in csv_reader:
        model_results.append(row)

# Create a bar plot for validation precision
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["precision"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation Precision")
plt.title("Validation Precision for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_precision_comparison.png"))
plt.close()

# Create a bar plot for validation recall
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["recall"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation Recall")
plt.title("Validation Recall for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_recall_comparison.png"))
plt.close()

# Create a bar plot for validation AUC-ROC
plt.figure(figsize=(10, 6))
plt.bar(range(len(model_results)), [float(result["auc"]) for result in model_results])
plt.xticks(
    range(len(model_results)),
    [f"{result['architecture']}_{result['optimizer']}" for result in model_results],
    rotation=45,
)
plt.xlabel("Model")
plt.ylabel("Validation AUC-ROC")
plt.title("Validation AUC-ROC for Different Models")
plt.tight_layout()
plt.savefig(os.path.join(visualizations_dir, "validation_auc_comparison.png"))
plt.close()
# Out:
# Found 2003 images belonging to 7 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step
# Confusion Matrix for VGG16_SGD:
# [[  4   5  13   4   6  32   1]
#  [  8   3  12   1  17  59   3]
#  [ 12  23  32   6  33 114   0]
#  [  2   4   2   0   3  12   0]
#  [  8  13  35   5  53 106   3]
#  [ 68 105 157  26 229 730  26]
#  [  4   3   1   0   5  14   1]]
# Classification Report for VGG16_SGD:
#               precision    recall  f1-score   support
#
#        akiec       0.04      0.06      0.05        65
#          bcc       0.02      0.03      0.02       103
#          bkl       0.13      0.15      0.14       220
#           df       0.00      0.00      0.00        23
#          mel       0.15      0.24      0.19       223
#           nv       0.68      0.54      0.61      1341
#         vasc       0.03      0.04      0.03        28
#
#     accuracy                           0.41      2003
#    macro avg       0.15      0.15      0.15      2003
# weighted avg       0.49      0.41      0.44      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 108s 2s/step
# Confusion Matrix for VGG16_Adam:
# [[  5   5   4   2  14  35   0]
#  [  9   8  13   0  16  54   3]
#  [ 12  21  15   6  44 122   0]
#  [  0   2   1   2   4  12   2]
#  [  9  14  33  12  34 114   7]
#  [ 81 112 165  34 245 683  21]
#  [  3   3   4   3   4  11   0]]
# Classification Report for VGG16_Adam:
#               precision    recall  f1-score   support
#
#        akiec       0.04      0.08      0.05        65
#          bcc       0.05      0.08      0.06       103
#          bkl       0.06      0.07      0.07       220
#           df       0.03      0.09      0.05        23
#          mel       0.09      0.15      0.12       223
#           nv       0.66      0.51      0.58      1341
#         vasc       0.00      0.00      0.00        28
#
#     accuracy                           0.37      2003
#    macro avg       0.13      0.14      0.13      2003
# weighted avg       0.47      0.37      0.41      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 17s 2s/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Found 2003 images belonging to 7 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 47s 732ms/step
# Confusion Matrix for ResNet50_SGD:
# [[  3   4   6   2  16  29   5]
#  [  4   7  13   0  20  57   2]
#  [  9  11  35  10  43 111   1]
#  [  0   0   1   0   4  17   1]
#  [ 13  14  24   5  52 113   2]
#  [ 67  95 158  30 273 693  25]
#  [  0   3   6   0   7  12   0]]
# Classification Report for ResNet50_SGD:
#               precision    recall  f1-score   support
#
#        akiec       0.03      0.05      0.04        65
#          bcc       0.05      0.07      0.06       103
#          bkl       0.14      0.16      0.15       220
#           df       0.00      0.00      0.00        23
#          mel       0.13      0.23      0.16       223
#           nv       0.67      0.52      0.58      1341
#         vasc       0.00      0.00      0.00        28
#
#     accuracy                           0.39      2003
#    macro avg       0.15      0.15      0.14      2003
# weighted avg       0.48      0.39      0.43      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 729ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 48s 741ms/step
# Confusion Matrix for ResNet50_Adam:
# [[  3   2  11   3  11  34   1]
#  [  9   6  10   0  26  50   2]
#  [ 13  13  29   6  46 109   4]
#  [  4   4   1   0   6   8   0]
#  [ 12  20  30   7  54  95   5]
#  [ 60  93 166  37 267 693  25]
#  [  2   1   2   0   8  12   3]]
# Classification Report for ResNet50_Adam:
#               precision    recall  f1-score   support
#
#        akiec       0.03      0.05      0.04        65
#          bcc       0.04      0.06      0.05       103
#          bkl       0.12      0.13      0.12       220
#           df       0.00      0.00      0.00        23
#          mel       0.13      0.24      0.17       223
#           nv       0.69      0.52      0.59      1341
#         vasc       0.07      0.11      0.09        28
#
#     accuracy                           0.39      2003
#    macro avg       0.16      0.16      0.15      2003
# weighted avg       0.49      0.39      0.43      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 735ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Found 2003 images belonging to 7 classes.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# c:\Users\Andrew Koller\anaconda3\envs\tf_new\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:120: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 838ms/step
# Confusion Matrix for InceptionV3_SGD:
# [[  6   7   7   4   9  28   4]
#  [  5   5  12   2  21  53   5]
#  [ 10  16  32   6  35 113   8]
#  [  0   2   4   1   4  12   0]
#  [  9  13  21   3  48 120   9]
#  [ 84 116 144  39 238 688  32]
#  [  3   4   5   0   7   9   0]]
# Classification Report for InceptionV3_SGD:
#               precision    recall  f1-score   support
#
#        akiec       0.05      0.09      0.07        65
#          bcc       0.03      0.05      0.04       103
#          bkl       0.14      0.15      0.14       220
#           df       0.02      0.04      0.03        23
#          mel       0.13      0.22      0.16       223
#           nv       0.67      0.51      0.58      1341
#         vasc       0.00      0.00      0.00        28
#
#     accuracy                           0.39      2003
#    macro avg       0.15      0.15      0.15      2003
# weighted avg       0.48      0.39      0.43      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 820ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 54s 831ms/step
# Confusion Matrix for InceptionV3_Adam:
# [[  4   4  11   1  15  30   0]
#  [  6   6  12   5  13  56   5]
#  [ 16  12  30  13  37  99  13]
#  [  3   1   2   1   3  11   2]
#  [ 11  13  31  13  33 115   7]
#  [ 86  97 160  47 244 667  40]
#  [  0   4   3   2   5  12   2]]
# Classification Report for InceptionV3_Adam:
#               precision    recall  f1-score   support
#
#        akiec       0.03      0.06      0.04        65
#          bcc       0.04      0.06      0.05       103
#          bkl       0.12      0.14      0.13       220
#           df       0.01      0.04      0.02        23
#          mel       0.09      0.15      0.12       223
#           nv       0.67      0.50      0.57      1341
#         vasc       0.03      0.07      0.04        28
#
#     accuracy                           0.37      2003
#    macro avg       0.14      0.15      0.14      2003
# weighted avg       0.48      0.37      0.41      2003
#
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 797ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
